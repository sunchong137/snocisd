# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.load("results/hchain1.4_sto3g_line.npy")

# %%
for i in range(6):
    d1 = data[i]
    plt.plot(d1[:,0], d1[:, 1])

# %%
idxs = range(6,12)
for i in idxs:
    d1 = data[i]
    plt.plot(d1[:,0], d1[:, 1])

# %%
idxs = range(12, 18)
for i in idxs:
    d1 = data[i]
    plt.plot(d1[:,0], d1[:, 1])
