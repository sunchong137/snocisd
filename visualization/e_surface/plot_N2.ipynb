# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib

# %%
data = np.load("results/N21.5_631g_esurf.npy")
x = data[:, 0]
y = data[:, 1]
z = data[:, 2]

# Z = z.reshape(X.shape)
fig = plt.figure()
ax = Axes3D(fig)
norm = matplotlib.colors.Normalize(vmin = np.min(z), vmax = np.max(z), clip = False)
c = cm.gist_rainbow_r
surf = ax.plot_trisurf(x, y, z, cmap=c, linewidth=0, norm=None, edgecolor = 'grey')
# fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel("Param1")
ax.set_ylabel("Param2")
# rotate the axes and update
theta = 20
phi = 90
ax.view_init(theta, phi)
# plt.draw()

# for angle in range(0, 360):
#     ax.view_init(30, angle)
#     plt.draw()
#     plt.pause(.001)
# Out:
# /tmp/ipykernel_16731/824716472.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
data = np.load("results/N21.5_sto3g_esurf.npy")
x = data[:, 0]
y = data[:, 1]
z = data[:, 2]

# Z = z.reshape(X.shape)
fig = plt.figure()
ax = Axes3D(fig)
norm = matplotlib.colors.Normalize(vmin = np.min(z), vmax = np.max(z), clip = False)
c = cm.gist_rainbow_r
surf = ax.plot_trisurf(x, y, z, cmap=c, linewidth=0, norm=None, edgecolor = 'grey')
# fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel("Param1")
ax.set_ylabel("Param2")
# rotate the axes and update
theta = 20
phi = 70
# phi = 180
ax.view_init(theta, phi)
# # plt.draw()

# # for angle in range(0, 360):
# #     ax.view_init(30, angle)
#     plt.draw()
#     plt.pause(.001)
# Out:
# /tmp/ipykernel_16731/4235009226.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
