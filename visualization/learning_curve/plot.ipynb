# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.loadtxt("results/hchain.txt")

# %%
ld = len(data)
x = np.arange(ld)

# %%
plt.plot(x, data)

# %%
plt.plot(x[100:230], data[100:230])
